# %% [markdown]
# # Problem Statement
#
#
# A banking institution requires actionable insights into mortgage-backed securities, geographic business investment, and real estate analysis.
# The mortgage bank would like to identify potential monthly mortgage expenses for each region based on monthly family income and rental of the real estate.
# A statistical model needs to be created to predict the potential demand in dollars amount of loan for each of the region in the USA. Also, there is a need to create a dashboard which would refresh periodically post data retrieval from the agencies.
# The dashboard must demonstrate relationships and trends for the key metrics as follows: number of loans, average rental income, monthly mortgage and owner’s cost, family income vs mortgage cost comparison across different regions. The metrics described here do not limit the dashboard to these few.
# Problem Statement
#
#
# A banking institution requires actionable insights into mortgage-backed securities, geographic business investment, and real estate analysis.
# The mortgage bank would like to identify potential monthly mortgage expenses for each region based on monthly family income and rental of the real estate.
# A statistical model needs to be created to predict the potential demand in dollars amount of loan for each of the region in the USA. Also, there is a need to create a dashboard which would refresh periodically post data retrieval from the agencies.
# The dashboard must demonstrate relationships and trends for the key metrics as follows: number of loans, average rental income, monthly mortgage and owner’s cost, family income vs mortgage cost comparison across different regions. The metrics described here do not limit the dashboard to these few.

# %%
##to begin with we will install the basic required packages for our project...

# %%
 from sklearn.preprocessing import StandardScaler

# %%
import pandas as pd
import numpy as np
from pandas_profiling import ProfileReport
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Now time to import the dataset into the project..

# %%
Real_Estate_df=pd.read_csv("train.csv");

# %%
Real_Estate_dfTest=pd.read_csv("test.csv");

# %%
prof = ProfileReport(Real_Estate_df)

# %%
max(Real_Estate_df['ALand'])
# Out:
# 103951000000.0

# %%
Real_Estate_df['ALand']
# Out:
# 0        2.021834e+08
# 1        1.560828e+06
# 2        6.956160e+07
# 3        1.105793e+06
# 4        2.554403e+06
#              ...
# 27316    6.970300e+05
# 27317    5.077337e+06
# 27318    1.323262e+09
# 27319    1.865230e+07
# 27320    7.796308e+06
# Name: ALand, Length: 27321, dtype: float64

# %%
Real_Estate_df['type']
# Out:
# 0           City
# 1           City
# 2           City
# 3          Urban
# 4           City
#           ...
# 27316      Urban
# 27317    Borough
# 27318       City
# 27319       Town
# 27320       City
# Name: type, Length: 27321, dtype: object

# %%
Real_Estate_dfTest.head()
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# 0  255504      NaN       140       163       26      Michigan       MI
# 1  252676      NaN       140         1       23         Maine       ME
# 2  276314      NaN       140        15       42  Pennsylvania       PA
# 3  248614      NaN       140       231       21      Kentucky       KY
# 4  286865      NaN       140       355       48         Texas       TX
#
#              city                  place     type  ... female_age_mean  \
# 0         Detroit  Dearborn Heights City      CDP  ...        34.78682
# 1          Auburn            Auburn City     City  ...        44.23451
# 2       Pine City              Millerton  Borough  ...        41.62426
# 3      Monticello        Monticello City     City  ...        44.81200
# 4  Corpus Christi                  Edroy     Town  ...        40.66618
#
#    female_age_median  female_age_stdev  female_age_sample_weight  \
# ...

# %%
Real_Estate_df.shape
# Out:
# (27321, 80)

# %%
Real_Estate_df.columns
# Out:
# Index(['UID', 'BLOCKID', 'SUMLEVEL', 'COUNTYID', 'STATEID', 'state',
#        'state_ab', 'city', 'place', 'type', 'primary', 'zip_code', 'area_code',
#        'lat', 'lng', 'ALand', 'AWater', 'pop', 'male_pop', 'female_pop',
#        'rent_mean', 'rent_median', 'rent_stdev', 'rent_sample_weight',
#        'rent_samples', 'rent_gt_10', 'rent_gt_15', 'rent_gt_20', 'rent_gt_25',
#        'rent_gt_30', 'rent_gt_35', 'rent_gt_40', 'rent_gt_50',
#        'universe_samples', 'used_samples', 'hi_mean', 'hi_median', 'hi_stdev',
#        'hi_sample_weight', 'hi_samples', 'family_mean', 'family_median',
#        'family_stdev', 'family_sample_weight', 'family_samples',
#        'hc_mortgage_mean', 'hc_mortgage_median', 'hc_mortgage_stdev',
#        'hc_mortgage_sample_weight', 'hc_mortgage_samples', 'hc_mean',
#        'hc_median', 'hc_stdev', 'hc_samples', 'hc_sample_weight',
#        'home_equity_second_mortgage', 'second_mortgage', 'home_equity', 'debt',
# ...

# %%
Real_Estate_df['UID'].value_counts()
# Out:
# 282028    4
# 230058    4
# 285596    3
# 235725    3
# 268775    3
#          ..
# 254569    1
# 260714    1
# 246381    1
# 273008    1
# 268291    1
# Name: UID, Length: 27161, dtype: int64

# %%
Real_Estate_df[Real_Estate_df['UID']==282028]
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID      state state_ab  \
# 16956  282028      NaN       140        93       47  Tennessee       TN
# 21160  282028      NaN       140        93       47  Tennessee       TN
# 21716  282028      NaN       140        93       47  Tennessee       TN
# 22393  282028      NaN       140        93       47  Tennessee       TN
#
#             city           place  type  ... female_age_mean  \
# 16956  Knoxville  Knoxville City  City  ...        19.19981
# 21160  Knoxville  Knoxville City  City  ...        19.19981
# 21716  Knoxville  Knoxville City  City  ...        19.19981
# 22393  Knoxville  Knoxville City  City  ...        19.19981
#
#        female_age_median  female_age_stdev  female_age_sample_weight  \
# 16956               19.0           1.48653                 468.23851
# 21160               19.0           1.48653                 468.23851
# 21716               19.0           1.48653                 468.23851
# ...

# %%
Real_Estate_df[Real_Estate_df['UID']==230058]
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID       state state_ab  \
# 777    230058      NaN       140        73        6  California       CA
# 1623   230058      NaN       140        73        6  California       CA
# 17489  230058      NaN       140        73        6  California       CA
# 26046  230058      NaN       140        73        6  California       CA
#
#             city                 place  type  ... female_age_mean  \
# 777    Oceanside  Camp Pendleton North  City  ...        19.99315
# 1623   Oceanside  Camp Pendleton North  City  ...        19.99315
# 17489  Oceanside  Camp Pendleton North  City  ...        19.99315
# 26046  Oceanside  Camp Pendleton North  City  ...        19.99315
#
#        female_age_median  female_age_stdev  female_age_sample_weight  \
# 777             22.41667          11.62088                3406.53918
# 1623            22.41667          11.62088                3406.53918
# ...

# %%
Real_Estate_df[Real_Estate_df['UID']==282028]
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID      state state_ab  \
# 16956  282028      NaN       140        93       47  Tennessee       TN
# 21160  282028      NaN       140        93       47  Tennessee       TN
# 21716  282028      NaN       140        93       47  Tennessee       TN
# 22393  282028      NaN       140        93       47  Tennessee       TN
#
#             city           place  type  ... female_age_mean  \
# 16956  Knoxville  Knoxville City  City  ...        19.19981
# 21160  Knoxville  Knoxville City  City  ...        19.19981
# 21716  Knoxville  Knoxville City  City  ...        19.19981
# 22393  Knoxville  Knoxville City  City  ...        19.19981
#
#        female_age_median  female_age_stdev  female_age_sample_weight  \
# 16956               19.0           1.48653                 468.23851
# 21160               19.0           1.48653                 468.23851
# 21716               19.0           1.48653                 468.23851
# ...

# %%
Real_Estate_df_unique=Real_Estate_df.drop_duplicates()

# %%
##As from the above analysis we have figured out that  uid is the unique/primary key in the dataset..

# %% [markdown]
# ##Requirement of indexing:
# 1.it helps in properly labeling the data rows of each column

# %%
Real_Estate_df.columns
# Out:
# Index(['UID', 'BLOCKID', 'SUMLEVEL', 'COUNTYID', 'STATEID', 'state',
#        'state_ab', 'city', 'place', 'type', 'primary', 'zip_code', 'area_code',
#        'lat', 'lng', 'ALand', 'AWater', 'pop', 'male_pop', 'female_pop',
#        'rent_mean', 'rent_median', 'rent_stdev', 'rent_sample_weight',
#        'rent_samples', 'rent_gt_10', 'rent_gt_15', 'rent_gt_20', 'rent_gt_25',
#        'rent_gt_30', 'rent_gt_35', 'rent_gt_40', 'rent_gt_50',
#        'universe_samples', 'used_samples', 'hi_mean', 'hi_median', 'hi_stdev',
#        'hi_sample_weight', 'hi_samples', 'family_mean', 'family_median',
#        'family_stdev', 'family_sample_weight', 'family_samples',
#        'hc_mortgage_mean', 'hc_mortgage_median', 'hc_mortgage_stdev',
#        'hc_mortgage_sample_weight', 'hc_mortgage_samples', 'hc_mean',
#        'hc_median', 'hc_stdev', 'hc_samples', 'hc_sample_weight',
#        'home_equity_second_mortgage', 'second_mortgage', 'home_equity', 'debt',
# ...

# %%
Real_Estate_df['primary'].value_counts()
# Out:
# tract    27321
# Name: primary, dtype: int64

# %%
Real_Estate_df
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# 0      267822      NaN       140        53       36      New York       NY
# 1      246444      NaN       140       141       18       Indiana       IN
# 2      245683      NaN       140        63       18       Indiana       IN
# 3      279653      NaN       140       127       72   Puerto Rico       PR
# 4      247218      NaN       140       161       20        Kansas       KS
# ...       ...      ...       ...       ...      ...           ...      ...
# 27316  279212      NaN       140        43       72   Puerto Rico       PR
# 27317  277856      NaN       140        91       42  Pennsylvania       PA
# 27318  233000      NaN       140        87        8      Colorado       CO
# 27319  287425      NaN       140       439       48         Texas       TX
# 27320  265371      NaN       140         3       32        Nevada       NV
#
# ...

# %%
Real_Estate_df_unique['SUMLEVEL'].unique()
# Out:
# array([140], dtype=int64)

# %%
Real_Estate_df_unique['UID'].value_counts()
# Out:
# 266238    1
# 288166    1
# 265643    1
# 275884    1
# 251312    1
#          ..
# 234119    1
# 256648    1
# 254601    1
# 252558    1
# 268291    1
# Name: UID, Length: 27161, dtype: int64

# %%
Real_Estate_df_unique.shape
# Out:
# (27161, 80)

# %%
Real_Estate_df_unique.head()
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID        state state_ab  \
# 0  267822      NaN       140        53       36     New York       NY
# 1  246444      NaN       140       141       18      Indiana       IN
# 2  245683      NaN       140        63       18      Indiana       IN
# 3  279653      NaN       140       127       72  Puerto Rico       PR
# 4  247218      NaN       140       161       20       Kansas       KS
#
#          city           place   type  ... female_age_mean  female_age_median  \
# 0    Hamilton        Hamilton   City  ...        44.48629           45.33333
# 1  South Bend        Roseland   City  ...        36.48391           37.58333
# 2    Danville        Danville   City  ...        42.15810           42.83333
# 3    San Juan        Guaynabo  Urban  ...        47.77526           50.58333
# 4   Manhattan  Manhattan City   City  ...        24.17693           21.58333
#
#    female_age_stdev  female_age_sample_weight  female_age_samples  pct_own  \
# ...

# %%
scaler = StandardScaler()

# %%
Real_Estate_df_unique.describe()
# Out:
#                  UID  BLOCKID  SUMLEVEL      COUNTYID       STATEID  \
# count   27161.000000      0.0   27161.0  27161.000000  27161.000000
# mean   257328.592209      NaN     140.0     85.660322     28.267185
# std     21342.667653      NaN       0.0     98.373195     16.385918
# min    220342.000000      NaN     140.0      1.000000      1.000000
# 25%    238826.000000      NaN     140.0     29.000000     13.000000
# 50%    257212.000000      NaN     140.0     63.000000     28.000000
# 75%    275810.000000      NaN     140.0    109.000000     42.000000
# max    294334.000000      NaN     140.0    840.000000     72.000000
#
#            zip_code     area_code           lat           lng         ALand  \
# count  27161.000000  27161.000000  27161.000000  27161.000000  2.716100e+04
# mean   50105.133243    596.589816     37.519180    -91.297136  1.300509e+08
# std    29546.218041    232.424069      5.585968     16.340783  1.279231e+09
# ...

# %%
##now we have to perform standard scaling on the data so that we can apply varoius algortihms and models on our data effectively

# %%
Real_Estate_df_unique['married']
# Out:
# 0        0.57851
# 1        0.34886
# 2        0.64745
# 3        0.47257
# 4        0.12356
#           ...
# 27316    0.24603
# 27317    0.61127
# 27318    0.70451
# 27319    0.75503
# 27320    0.34426
# Name: married, Length: 27161, dtype: float64

# %%
Real_Estate_df_unique.dtypes.unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('O')], dtype=object)

# %%
obj_values=[]

# %%
numerical_values=[]

# %%
for i in  Real_Estate_df_unique.columns:
    if(Real_Estate_df_unique[i].dtype=='int64'or Real_Estate_df_unique[i].dtype=='float64'):
        numerical_values.append(i)
    if(Real_Estate_df_unique[i].dtype=='O'):
        obj_values.append(i)

# %%
obj_values
# Out:
# ['state', 'state_ab', 'city', 'place', 'type', 'primary']

# %%
numerical_values
# Out:
# ['UID',
#  'BLOCKID',
#  'SUMLEVEL',
#  'COUNTYID',
#  'STATEID',
#  'zip_code',
#  'area_code',
#  'lat',
#  'lng',
#  'ALand',
#  'AWater',
#  'pop',
#  'male_pop',
#  'female_pop',
#  'rent_mean',
#  'rent_median',
#  'rent_stdev',
#  'rent_sample_weight',
#  'rent_samples',
#  'rent_gt_10',
#  'rent_gt_15',
#  'rent_gt_20',
#  'rent_gt_25',
#  'rent_gt_30',
#  'rent_gt_35',
#  'rent_gt_40',
#  'rent_gt_50',
#  'universe_samples',
#  'used_samples',
#  'hi_mean',
#  'hi_median',
#  'hi_stdev',
#  'hi_sample_weight',
#  'hi_samples',
#  'family_mean',
#  'family_median',
#  'family_stdev',
#  'family_sample_weight',
#  'family_samples',
#  'hc_mortgage_mean',
#  'hc_mortgage_median',
#  'hc_mortgage_stdev',
#  'hc_mortgage_sample_weight',
#  'hc_mortgage_samples',
#  'hc_mean',
#  'hc_median',
#  'hc_stdev',
#  'hc_samples',
#  'hc_sample_weight',
#  'home_equity_second_mortgage',
#  'second_mortgage',
#  'home_equity',
#  'debt',
#  'second_mortgage_cdf',
#  'home_equity_cdf',
# ...

# %%
# numerical_values.remove('divorced')

# %%
numerical_dfREalEstate=Real_Estate_df_unique[numerical_values]

# %%
numerical_dfREalEstate
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID  zip_code  area_code  \
# 0      267822      NaN       140        53       36     13346        315
# 1      246444      NaN       140       141       18     46616        574
# 2      245683      NaN       140        63       18     46122        317
# 3      279653      NaN       140       127       72       927        787
# 4      247218      NaN       140       161       20     66502        785
# ...       ...      ...       ...       ...      ...       ...        ...
# 27316  279212      NaN       140        43       72       769        787
# 27317  277856      NaN       140        91       42     19422        215
# 27318  233000      NaN       140        87        8     80653        970
# 27319  287425      NaN       140       439       48     76034        817
# 27320  265371      NaN       140         3       32     89123        702
#
#              lat         lng         ALand  ...  female_age_mean  \
# ...

# %%
numerical_dfREalEstate['BLOCKID'].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 27316    True
# 27317    True
# 27318    True
# 27319    True
# 27320    True
# Name: BLOCKID, Length: 27161, dtype: bool

# %%
##as the whole column is null we will drop it

# %%
Real_Estate_df_unique.shape
# Out:
# (27161, 80)

# %%
len(numerical_values)
# Out:
# 74

# %%
numerical_dfREalEstate
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID  zip_code  area_code  \
# 0      267822      NaN       140        53       36     13346        315
# 1      246444      NaN       140       141       18     46616        574
# 2      245683      NaN       140        63       18     46122        317
# 3      279653      NaN       140       127       72       927        787
# 4      247218      NaN       140       161       20     66502        785
# ...       ...      ...       ...       ...      ...       ...        ...
# 27316  279212      NaN       140        43       72       769        787
# 27317  277856      NaN       140        91       42     19422        215
# 27318  233000      NaN       140        87        8     80653        970
# 27319  287425      NaN       140       439       48     76034        817
# 27320  265371      NaN       140         3       32     89123        702
#
#              lat         lng         ALand  ...  female_age_mean  \
# ...

# %%
numerical_dfREalEstate.drop(['BLOCKID'],inplace=True,axis=1)
# Out:
# C:\Users\athan\AppData\Roaming\Python\Python38\site-packages\pandas\core\frame.py:3990: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
scaler.fit(numerical_dfREalEstate)
# Out:
# StandardScaler()

# %%
numerical_scalesdf=scaler.transform(numerical_dfREalEstate)

# %%
numerical_scalesdf
# Out:
# array([[ 0.49167242,  0.        , -0.33201039, ..., -0.76768865,
#         -0.32170018, -0.25991007],
#        [-0.5100015 ,  0.        ,  0.5625587 , ..., -0.8904158 ,
#         -0.23203541, -0.20663869],
#        [-0.54565843,  0.        , -0.23035481, ..., -0.51254536,
#         -0.14478099,  0.12671722],
#        ...,
#        [-1.13992498,  0.        ,  0.01361858, ..., -0.90118134,
#         -0.66878961, -0.47668361],
#        [ 1.41017807,  0.        ,  3.59189497, ..., -0.65868756,
#         -0.47837249, -0.97886882],
#        [ 0.37682992,  0.        , -0.84028829, ..., -0.24475256,
#          0.52915099,  0.67233909]])

# %%
numerical_scalesdf.shape
# Out:
# (27161, 73)

# %%
##we are looking at the second mortgage values main values..

# %%
Real_Estate_df_unique['second_mortgage'].value_counts()
# Out:
# 0.00000    5079
# 0.05556      19
# 0.02500      18
# 0.02222      18
# 0.02041      18
#            ...
# 0.15226       1
# 0.05784       1
# 0.03004       1
# 0.01228       1
# 0.01710       1
# Name: second_mortgage, Length: 7821, dtype: int64

# %%
Real_Estate_df_unique['second_mortgage_cdf'].value_counts()
# Out:
# 1.00000    5079
# 0.17697      19
# 0.39441      19
# 0.33636      19
# 0.42174      18
#            ...
# 0.21778       1
# 0.12968       1
# 0.34484       1
# 0.27754       1
# 0.27621       1
# Name: second_mortgage_cdf, Length: 13751, dtype: int64

# %%
Real_Estate_df['home_equity'].value_counts()
# Out:
# 0.00000    1518
# 0.12500      28
# 0.08333      26
# 0.14286      25
# 0.10000      19
#            ...
# 0.11399       1
# 0.13431       1
# 0.21717       1
# 0.02203       1
# 0.00808       1
# Name: home_equity, Length: 14578, dtype: int64

# %%
Real_Estate_df['hc_mortgage_samples'].value_counts()
# Out:
# 513.0     41
# 468.0     40
# 495.0     38
# 422.0     38
# 402.0     38
#           ..
# 2287.0     1
# 2354.0     1
# 3533.0     1
# 2335.0     1
# 1821.0     1
# Name: hc_mortgage_samples, Length: 2193, dtype: int64

# %%
Real_Estate_df['hc_samples'].value_counts()
# Out:
# 239.0     72
# 302.0     70
# 156.0     68
# 192.0     67
# 280.0     64
#           ..
# 1486.0     1
# 1169.0     1
# 1125.0     1
# 958.0      1
# 1031.0     1
# Name: hc_samples, Length: 1298, dtype: int64

# %%
Real_Estate_df_unique.head()
# Out:
#       UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID        state state_ab  \
# 0  267822      NaN       140        53       36     New York       NY
# 1  246444      NaN       140       141       18      Indiana       IN
# 2  245683      NaN       140        63       18      Indiana       IN
# 3  279653      NaN       140       127       72  Puerto Rico       PR
# 4  247218      NaN       140       161       20       Kansas       KS
#
#          city           place   type  ... female_age_mean  female_age_median  \
# 0    Hamilton        Hamilton   City  ...        44.48629           45.33333
# 1  South Bend        Roseland   City  ...        36.48391           37.58333
# 2    Danville        Danville   City  ...        42.15810           42.83333
# 3    San Juan        Guaynabo  Urban  ...        47.77526           50.58333
# 4   Manhattan  Manhattan City   City  ...        24.17693           21.58333
#
#    female_age_stdev  female_age_sample_weight  female_age_samples  pct_own  \
# ...

# %%
Real_Estatedf_home_equitynone=Real_Estate_df_unique.loc[Real_Estate_df_unique['home_equity_second_mortgage'].isnull() == True ]

# %%
Real_Estatedf_home_equitynone['home_equity_second_mortgage']
# Out:
# 51      NaN
# 94      NaN
# 302     NaN
# 340     NaN
# 356     NaN
#          ..
# 26875   NaN
# 27067   NaN
# 27072   NaN
# 27077   NaN
# 27240   NaN
# Name: home_equity_second_mortgage, Length: 360, dtype: float64

# %%
Real_Estate_df_unique['home_equity'].isnull().value_counts()
# Out:
# False    26801
# True       360
# Name: home_equity, dtype: int64

# %%
Real_Estate_df_unique['hc_mean'].isnull().value_counts()
# Out:
# False    26683
# True       478
# Name: hc_mean, dtype: int64

# %%
Real_Estate_df_unique['hc_median'].isnull().value_counts()
# Out:
# False    26683
# True       478
# Name: hc_median, dtype: int64

# %%
Real_Estate_df_unique['rent_mean'].isnull().value_counts()
# Out:
# False    26919
# True       242
# Name: rent_mean, dtype: int64

# %%
Real_Estate_df_unique['rent_median'].isnull().value_counts()
# Out:
# False    26919
# True       242
# Name: rent_median, dtype: int64

# %%
Real_Estate_df_unique['hs_degree'].isnull().value_counts()
# Out:
# False    27016
# True       145
# Name: hs_degree, dtype: int64

# %%
Real_Estate_df_unique['pop'].isnull().value_counts()
# Out:
# False    27161
# Name: pop, dtype: int64

# %%
Real_Estate_df_unique['male_pop'].isnull().value_counts()
# Out:
# False    27161
# Name: male_pop, dtype: int64

# %%
Real_Estate_df_unique['male_pop'].value_counts()
# Out:
# 0       148
# 2103     27
# 1575     23
# 2058     22
# 1768     22
#        ...
# 4491      1
# 4912      1
# 409       1
# 4246      1
# 5414      1
# Name: male_pop, Length: 4507, dtype: int64

# %%
Real_Estate_df_unique['male_age_median'].isnull().value_counts()
# Out:
# False    27013
# True       148
# Name: male_age_median, dtype: int64

# %%
Real_Estate_df_unique['family_mean'].isnull().value_counts()
# Out:
# False    26931
# True       230
# Name: family_mean, dtype: int64

# %%
Real_Estate_df_unique['hi_mean'].isnull().value_counts()
# Out:
# False    26954
# True       207
# Name: hi_mean, dtype: int64

# %%
Real_Estate_df_unique['hi_median'].isnull().value_counts()
# Out:
# False    26954
# True       207
# Name: hi_median, dtype: int64

# %%
##lokking at there are many missing values in different variables of the dataset..
##we will use the knn imputer for imputing the values

# %%
numerical_dfREalEstate.shape
# Out:
# (27161, 73)

# %%
Real_Estate_df_unique.shape
# Out:
# (27161, 80)

# %%
numerical_dfREalEstate
# Out:
#           UID  SUMLEVEL  COUNTYID  STATEID  zip_code  area_code        lat  \
# 0      267822       140        53       36     13346        315  42.840812
# 1      246444       140       141       18     46616        574  41.701441
# 2      245683       140        63       18     46122        317  39.792202
# 3      279653       140       127       72       927        787  18.396103
# 4      247218       140       161       20     66502        785  39.195573
# ...       ...       ...       ...      ...       ...        ...        ...
# 27316  279212       140        43       72       769        787  18.076060
# 27317  277856       140        91       42     19422        215  40.158138
# 27318  233000       140        87        8     80653        970  40.410316
# 27319  287425       140       439       48     76034        817  32.904866
# 27320  265371       140         3       32     89123        702  36.064754
#
#               lng         ALand    AWater  ...  female_age_mean  \
# ...

# %%
numerical_dfREalEstate.to_csv("numerical_dfREalEstate.csv",index=False)

# %%
Real_Estate_df_unique.to_csv("Real_estatedf_unique.csv",index=False)

# %%
Real_Estate_df_unique
# Out:
#           UID  BLOCKID  SUMLEVEL  COUNTYID  STATEID         state state_ab  \
# 0      267822      NaN       140        53       36      New York       NY
# 1      246444      NaN       140       141       18       Indiana       IN
# 2      245683      NaN       140        63       18       Indiana       IN
# 3      279653      NaN       140       127       72   Puerto Rico       PR
# 4      247218      NaN       140       161       20        Kansas       KS
# ...       ...      ...       ...       ...      ...           ...      ...
# 27316  279212      NaN       140        43       72   Puerto Rico       PR
# 27317  277856      NaN       140        91       42  Pennsylvania       PA
# 27318  233000      NaN       140        87        8      Colorado       CO
# 27319  287425      NaN       140       439       48         Texas       TX
# 27320  265371      NaN       140         3       32        Nevada       NV
#
# ...

# %%
numerical_scalesdf.to_csv("numerical_scalesdf.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-994003c76ed1> in <module>
# ----> 1 numerical_scalesdf.to_csv("numerical_scalesdf.csv",index=False)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'to_csv'

# %%
numerical_scalesdf

# %%
freshDatafrme_nn = pd.DataFrame(freshdf_numerical, columns = list(fresh_dataFrame.columns))
